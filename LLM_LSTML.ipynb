# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import random


#Load and Tokenize Data
##################################

#Load the text file
with open('last_data.txt', 'r', encoding='utf-8') as f:
    text = f.read()

#Character-level tokenization
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(f"Unique characters in the dataset: {vocab_size}")

#Create mappings
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

#Encode the entire text into integers
encoded = [char_to_idx[ch] for ch in text]
encoded = torch.tensor(encoded, dtype=torch.long)

#Train-validation split
split_ratio = 0.9
n = int(split_ratio * len(encoded))
train_data = encoded[:n]
val_data = encoded[n:]


#Dataset Class
##############################################################

class TextDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = self.data[idx:idx+self.block_size]
        y = self.data[idx+1:idx+self.block_size+1]
        return x, y

block_size = 32
train_dataset = TextDataset(train_data, block_size)
val_dataset = TextDataset(val_data, block_size)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, drop_last=True)


#LSTM-Based Language Model
################################################################

class LSTMLanguageModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden_state=None):
        # Embed tokens
        x = self.embedding(x)  # (B, T, embedding_dim)

        # Pass through LSTM
        if hidden_state is None:
            output, hidden_state = self.lstm(x)  # (B, T, hidden_dim)
        else:
            output, hidden_state = self.lstm(x, hidden_state)

        # Project to vocab size
        logits = self.fc(output)  # (B, T, vocab_size)
        return logits, hidden_state


#Training Setup
##########################################################

device = 'cuda' if torch.cuda.is_available() else 'cpu'

vocab_size = len(chars)
embedding_dim = 128
hidden_dim = 256
num_layers = 2

model = LSTMLanguageModel(vocab_size, embedding_dim, hidden_dim, num_layers).to(device)
optimizer = optim.Adam(model.parameters(), lr=3e-4)
criterion = nn.CrossEntropyLoss()


#Training Loop
############################################################

model.train()
num_epochs = 1  #Increase for better training
for epoch in range(num_epochs):
    for step, (x_batch, y_batch) in enumerate(train_loader):
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        logits, _ = model(x_batch)  # (B, T, vocab_size)
        B, T, V = logits.shape
        loss = criterion(logits.view(B*T, V), y_batch.view(B*T))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 100 == 0:
            print(f"Epoch {epoch}, Step {step}, Loss: {loss.item():.4f}")


# Evaluation
######################################################

model.eval()
val_loss = 0
val_steps = 0
with torch.no_grad():
    for x_batch, y_batch in val_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        logits, _ = model(x_batch)
        B, T, V = logits.shape
        loss = criterion(logits.view(B*T, V), y_batch.view(B*T))
        val_loss += loss.item()
        val_steps += 1
val_loss /= val_steps
print(f"Validation loss: {val_loss:.4f}")


# Text Generation
#################################################

def generate_text(model, start_char, char_to_idx, idx_to_char, max_length=500):
    model.eval()
    input_idx = torch.tensor([[char_to_idx[start_char]]], dtype=torch.long).to(device)
    generated_text = [start_char]

    hidden_state = None
    with torch.no_grad():
        for _ in range(max_length):
            logits, hidden_state = model(input_idx, hidden_state)  #(1, 1, vocab_size)
            probs = torch.softmax(logits[0, -1, :], dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            next_char = idx_to_char[next_token.item()]
            generated_text.append(next_char)
            input_idx = next_token.unsqueeze(0)

    return ''.join(generated_text)

#Start text generation
random_start_char = random.choice(list(char_to_idx.keys()))
print(f"Starting generation with random character: {random_start_char}")
generated_text = generate_text(model, random_start_char, char_to_idx, idx_to_char)
print("Generated text:")
print(generated_text)
# Out:
# Unique characters in the dataset: 75
# Epoch 0, Step 0, Loss: 4.3091
# Epoch 0, Step 100, Loss: 2.9286
# Epoch 0, Step 200, Loss: 2.5332
# Epoch 0, Step 300, Loss: 2.4774
# Epoch 0, Step 400, Loss: 2.3912
# Epoch 0, Step 500, Loss: 2.2219
# Epoch 0, Step 600, Loss: 2.1376
# Epoch 0, Step 700, Loss: 2.0660
# Epoch 0, Step 800, Loss: 2.1510
# Epoch 0, Step 900, Loss: 2.0758
# Epoch 0, Step 1000, Loss: 2.1155
# Epoch 0, Step 1100, Loss: 2.0024
# Epoch 0, Step 1200, Loss: 1.9641
# Epoch 0, Step 1300, Loss: 1.9954
# Epoch 0, Step 1400, Loss: 2.0020
# Epoch 0, Step 1500, Loss: 1.9022
# Epoch 0, Step 1600, Loss: 1.8235
# Epoch 0, Step 1700, Loss: 1.8522
# Epoch 0, Step 1800, Loss: 1.8937
# Epoch 0, Step 1900, Loss: 1.8449
# Epoch 0, Step 2000, Loss: 1.8247
# Epoch 0, Step 2100, Loss: 1.9656
# Epoch 0, Step 2200, Loss: 1.8165
# Epoch 0, Step 2300, Loss: 1.7533
# Epoch 0, Step 2400, Loss: 1.7896
# Epoch 0, Step 2500, Loss: 1.8126
# Epoch 0, Step 2600, Loss: 1.6990
# Epoch 0, Step 2700, Loss: 1.7064
# Epoch 0, Step 2800, Loss: 1.7683
# Epoch 0, Step 2900, Loss: 1.5417
# Epoch 0, Step 3000, Loss: 1.7557
# Epoch 0, Step 3100, Loss: 1.6676
# Epoch 0, Step 3200, Loss: 1.7236
# Epoch 0, Step 3300, Loss: 1.7396
# Epoch 0, Step 3400, Loss: 1.7046
# Epoch 0, Step 3500, Loss: 1.5703
# Epoch 0, Step 3600, Loss: 1.6970
# Epoch 0, Step 3700, Loss: 1.7370
# Epoch 0, Step 3800, Loss: 1.6062
# Epoch 0, Step 3900, Loss: 1.6607
# Epoch 0, Step 4000, Loss: 1.5749
# Epoch 0, Step 4100, Loss: 1.6792
# Epoch 0, Step 4200, Loss: 1.6494
# Epoch 0, Step 4300, Loss: 1.5592
# Epoch 0, Step 4400, Loss: 1.4972
# Epoch 0, Step 4500, Loss: 1.7058
# Epoch 0, Step 4600, Loss: 1.6068
# Epoch 0, Step 4700, Loss: 1.4967
# Epoch 0, Step 4800, Loss: 1.6230
# Epoch 0, Step 4900, Loss: 1.5389
# Epoch 0, Step 5000, Loss: 1.6227
# Epoch 0, Step 5100, Loss: 1.5780
# Epoch 0, Step 5200, Loss: 1.5406
# Epoch 0, Step 5300, Loss: 1.5725
# Epoch 0, Step 5400, Loss: 1.5439
# Epoch 0, Step 5500, Loss: 1.6432
# Epoch 0, Step 5600, Loss: 1.5565
# Epoch 0, Step 5700, Loss: 1.6034
# Epoch 0, Step 5800, Loss: 1.4996
# Epoch 0, Step 5900, Loss: 1.5561
# Epoch 0, Step 6000, Loss: 1.6149
# Epoch 0, Step 6100, Loss: 1.5227
# Epoch 0, Step 6200, Loss: 1.6011
# Epoch 0, Step 6300, Loss: 1.5653
# Epoch 0, Step 6400, Loss: 1.5603
# Epoch 0, Step 6500, Loss: 1.7125
# Epoch 0, Step 6600, Loss: 1.4701
# Epoch 0, Step 6700, Loss: 1.5280
# Epoch 0, Step 6800, Loss: 1.5310
# Epoch 0, Step 6900, Loss: 1.5758
# Epoch 0, Step 7000, Loss: 1.5097
# Epoch 0, Step 7100, Loss: 1.5685
# Epoch 0, Step 7200, Loss: 1.5900
# Epoch 0, Step 7300, Loss: 1.4557
# Epoch 0, Step 7400, Loss: 1.4658
# Epoch 0, Step 7500, Loss: 1.5784
# Epoch 0, Step 7600, Loss: 1.4162
# Epoch 0, Step 7700, Loss: 1.4555
# Epoch 0, Step 7800, Loss: 1.4370
# Epoch 0, Step 7900, Loss: 1.5515
# Epoch 0, Step 8000, Loss: 1.4355
# Epoch 0, Step 8100, Loss: 1.5398
# Epoch 0, Step 8200, Loss: 1.5901
# Epoch 0, Step 8300, Loss: 1.4523
# Epoch 0, Step 8400, Loss: 1.5581
# Epoch 0, Step 8500, Loss: 1.4996
# Epoch 0, Step 8600, Loss: 1.4850
# Epoch 0, Step 8700, Loss: 1.4760
# Epoch 0, Step 8800, Loss: 1.4548
# Epoch 0, Step 8900, Loss: 1.5233
# Epoch 0, Step 9000, Loss: 1.5554
# Epoch 0, Step 9100, Loss: 1.3711
# Epoch 0, Step 9200, Loss: 1.4492
# Epoch 0, Step 9300, Loss: 1.4438
# Epoch 0, Step 9400, Loss: 1.4514
# Epoch 0, Step 9500, Loss: 1.5675
# Epoch 0, Step 9600, Loss: 1.4557
# Epoch 0, Step 9700, Loss: 1.5833
# Epoch 0, Step 9800, Loss: 1.5749
# Epoch 0, Step 9900, Loss: 1.5009
# Epoch 0, Step 10000, Loss: 1.3922
# Epoch 0, Step 10100, Loss: 1.4776
# Epoch 0, Step 10200, Loss: 1.5252
# Epoch 0, Step 10300, Loss: 1.4444
# Epoch 0, Step 10400, Loss: 1.4296
# Epoch 0, Step 10500, Loss: 1.5521
# Epoch 0, Step 10600, Loss: 1.3842
# Epoch 0, Step 10700, Loss: 1.3326
# Epoch 0, Step 10800, Loss: 1.4907
# Epoch 0, Step 10900, Loss: 1.3664
# Epoch 0, Step 11000, Loss: 1.4586
# Epoch 0, Step 11100, Loss: 1.3551
# Epoch 0, Step 11200, Loss: 1.4445
# Epoch 0, Step 11300, Loss: 1.4512
# Epoch 0, Step 11400, Loss: 1.3657
# Epoch 0, Step 11500, Loss: 1.3619
# Epoch 0, Step 11600, Loss: 1.3504
# Epoch 0, Step 11700, Loss: 1.4692
# Epoch 0, Step 11800, Loss: 1.4667
# Epoch 0, Step 11900, Loss: 1.6107
# Epoch 0, Step 12000, Loss: 1.4402
# Epoch 0, Step 12100, Loss: 1.4469
# Epoch 0, Step 12200, Loss: 1.4179
# Epoch 0, Step 12300, Loss: 1.4013
# Epoch 0, Step 12400, Loss: 1.3756
# Epoch 0, Step 12500, Loss: 1.5390
# Epoch 0, Step 12600, Loss: 1.4470
# Epoch 0, Step 12700, Loss: 1.3842
# Epoch 0, Step 12800, Loss: 1.4066
# Epoch 0, Step 12900, Loss: 1.3124
# Epoch 0, Step 13000, Loss: 1.4426
# Epoch 0, Step 13100, Loss: 1.4120
# Epoch 0, Step 13200, Loss: 1.3832
# Epoch 0, Step 13300, Loss: 1.3535
# Epoch 0, Step 13400, Loss: 1.4185
# Epoch 0, Step 13500, Loss: 1.4536
# Epoch 0, Step 13600, Loss: 1.3533
# Epoch 0, Step 13700, Loss: 1.4075
# Epoch 0, Step 13800, Loss: 1.3579
# Epoch 0, Step 13900, Loss: 1.4658
# Epoch 0, Step 14000, Loss: 1.3759
# Epoch 0, Step 14100, Loss: 1.3831
# Epoch 0, Step 14200, Loss: 1.3899
# Epoch 0, Step 14300, Loss: 1.2691
# Epoch 0, Step 14400, Loss: 1.2956
# Epoch 0, Step 14500, Loss: 1.4761
# Epoch 0, Step 14600, Loss: 1.4646
# Epoch 0, Step 14700, Loss: 1.3767
# Epoch 0, Step 14800, Loss: 1.5094
# Epoch 0, Step 14900, Loss: 1.2626
# Epoch 0, Step 15000, Loss: 1.3859
# Epoch 0, Step 15100, Loss: 1.4096
# Epoch 0, Step 15200, Loss: 1.3106
# Epoch 0, Step 15300, Loss: 1.2905
# Epoch 0, Step 15400, Loss: 1.4159
# Epoch 0, Step 15500, Loss: 1.3097
# Epoch 0, Step 15600, Loss: 1.3455
# Epoch 0, Step 15700, Loss: 1.2797
# Epoch 0, Step 15800, Loss: 1.3914
# Epoch 0, Step 15900, Loss: 1.3304
# Epoch 0, Step 16000, Loss: 1.3875
# Epoch 0, Step 16100, Loss: 1.4239
# Epoch 0, Step 16200, Loss: 1.3763
# Epoch 0, Step 16300, Loss: 1.4103
# Epoch 0, Step 16400, Loss: 1.3375
# Epoch 0, Step 16500, Loss: 1.2943
# Epoch 0, Step 16600, Loss: 1.3367
# Epoch 0, Step 16700, Loss: 1.4761
# Epoch 0, Step 16800, Loss: 1.4849
# Epoch 0, Step 16900, Loss: 1.3158
# Epoch 0, Step 17000, Loss: 1.3024
# Epoch 0, Step 17100, Loss: 1.3316
# Epoch 0, Step 17200, Loss: 1.3607
# Epoch 0, Step 17300, Loss: 1.4538
# Epoch 0, Step 17400, Loss: 1.4652
# Epoch 0, Step 17500, Loss: 1.3016
# Epoch 0, Step 17600, Loss: 1.3400
# Epoch 0, Step 17700, Loss: 1.4227
# Epoch 0, Step 17800, Loss: 1.3570
# Epoch 0, Step 17900, Loss: 1.3646
# Epoch 0, Step 18000, Loss: 1.4107
# Epoch 0, Step 18100, Loss: 1.3703
# Epoch 0, Step 18200, Loss: 1.3179
# Epoch 0, Step 18300, Loss: 1.2558
# Epoch 0, Step 18400, Loss: 1.3781
# Epoch 0, Step 18500, Loss: 1.2117
# Epoch 0, Step 18600, Loss: 1.3241
# Epoch 0, Step 18700, Loss: 1.4431
# Epoch 0, Step 18800, Loss: 1.4753
# Epoch 0, Step 18900, Loss: 1.3748
# Epoch 0, Step 19000, Loss: 1.4653
# Epoch 0, Step 19100, Loss: 1.5270
# Epoch 0, Step 19200, Loss: 1.2963
# Epoch 0, Step 19300, Loss: 1.2819
# Epoch 0, Step 19400, Loss: 1.4285
# Epoch 0, Step 19500, Loss: 1.3241
# Epoch 0, Step 19600, Loss: 1.2903
# Epoch 0, Step 19700, Loss: 1.3887
# Epoch 0, Step 19800, Loss: 1.3597
# Epoch 0, Step 19900, Loss: 1.4165
# Epoch 0, Step 20000, Loss: 1.3028
# Epoch 0, Step 20100, Loss: 1.3961
# Epoch 0, Step 20200, Loss: 1.2881
# Epoch 0, Step 20300, Loss: 1.4650
# Epoch 0, Step 20400, Loss: 1.3647
# Epoch 0, Step 20500, Loss: 1.2713
# Epoch 0, Step 20600, Loss: 1.3692
# Epoch 0, Step 20700, Loss: 1.3953
# Epoch 0, Step 20800, Loss: 1.2872
# Epoch 0, Step 20900, Loss: 1.3145
# Epoch 0, Step 21000, Loss: 1.2893
# Epoch 0, Step 21100, Loss: 1.4754
# Epoch 0, Step 21200, Loss: 1.4581
# Epoch 0, Step 21300, Loss: 1.3485
# Epoch 0, Step 21400, Loss: 1.3097
# Epoch 0, Step 21500, Loss: 1.3532
# Epoch 0, Step 21600, Loss: 1.2241
# Epoch 0, Step 21700, Loss: 1.3342
# Epoch 0, Step 21800, Loss: 1.3014
# Epoch 0, Step 21900, Loss: 1.2525
# Epoch 0, Step 22000, Loss: 1.2494
# Epoch 0, Step 22100, Loss: 1.3718
# Epoch 0, Step 22200, Loss: 1.3017
# Epoch 0, Step 22300, Loss: 1.2900
# Epoch 0, Step 22400, Loss: 1.2629
# Epoch 0, Step 22500, Loss: 1.2445
# Epoch 0, Step 22600, Loss: 1.4099
# Epoch 0, Step 22700, Loss: 1.3382
# Epoch 0, Step 22800, Loss: 1.3626
# Epoch 0, Step 22900, Loss: 1.3367
# Epoch 0, Step 23000, Loss: 1.3086
# Epoch 0, Step 23100, Loss: 1.3438
# Epoch 0, Step 23200, Loss: 1.3629
# Epoch 0, Step 23300, Loss: 1.3492
# Epoch 0, Step 23400, Loss: 1.3336
# Epoch 0, Step 23500, Loss: 1.2483
# Epoch 0, Step 23600, Loss: 1.3696
# Epoch 0, Step 23700, Loss: 1.3088
# Epoch 0, Step 23800, Loss: 1.2030
# Epoch 0, Step 23900, Loss: 1.2881
# Epoch 0, Step 24000, Loss: 1.3345
# Epoch 0, Step 24100, Loss: 1.2290
# Epoch 0, Step 24200, Loss: 1.2832
# Epoch 0, Step 24300, Loss: 1.3183
# Epoch 0, Step 24400, Loss: 1.3779
# Epoch 0, Step 24500, Loss: 1.3178
# Epoch 0, Step 24600, Loss: 1.4288
# Epoch 0, Step 24700, Loss: 1.3392
# Epoch 0, Step 24800, Loss: 1.3261
# Epoch 0, Step 24900, Loss: 1.3834
# Epoch 0, Step 25000, Loss: 1.3412
# Epoch 0, Step 25100, Loss: 1.2422
# Epoch 0, Step 25200, Loss: 1.3579
# Epoch 0, Step 25300, Loss: 1.3339
# Epoch 0, Step 25400, Loss: 1.3160
# Epoch 0, Step 25500, Loss: 1.2922
# Epoch 0, Step 25600, Loss: 1.2591
# Epoch 0, Step 25700, Loss: 1.3674
# Epoch 0, Step 25800, Loss: 1.2962
# Epoch 0, Step 25900, Loss: 1.2836
# Epoch 0, Step 26000, Loss: 1.3720
# Epoch 0, Step 26100, Loss: 1.2091
# Epoch 0, Step 26200, Loss: 1.2855
# Epoch 0, Step 26300, Loss: 1.3346
# Epoch 0, Step 26400, Loss: 1.2067
# Epoch 0, Step 26500, Loss: 1.2915
# Epoch 0, Step 26600, Loss: 1.3448
# Epoch 0, Step 26700, Loss: 1.3715
# Epoch 0, Step 26800, Loss: 1.3613
# Epoch 0, Step 26900, Loss: 1.2775
# Epoch 0, Step 27000, Loss: 1.4494
# Epoch 0, Step 27100, Loss: 1.2993
# Epoch 0, Step 27200, Loss: 1.2510
# Epoch 0, Step 27300, Loss: 1.2320
# Epoch 0, Step 27400, Loss: 1.2568
# Epoch 0, Step 27500, Loss: 1.2703
# Epoch 0, Step 27600, Loss: 1.3010
# Epoch 0, Step 27700, Loss: 1.4143
# Epoch 0, Step 27800, Loss: 1.2420
# Epoch 0, Step 27900, Loss: 1.2633
# Epoch 0, Step 28000, Loss: 1.2713
# Epoch 0, Step 28100, Loss: 1.2537
# Epoch 0, Step 28200, Loss: 1.3720
# Epoch 0, Step 28300, Loss: 1.3053
# Epoch 0, Step 28400, Loss: 1.2647
# Epoch 0, Step 28500, Loss: 1.3081
# Epoch 0, Step 28600, Loss: 1.2782
# Epoch 0, Step 28700, Loss: 1.3291
# Epoch 0, Step 28800, Loss: 1.2613
# Epoch 0, Step 28900, Loss: 1.3174
# Epoch 0, Step 29000, Loss: 1.3223
# Epoch 0, Step 29100, Loss: 1.2843
# Epoch 0, Step 29200, Loss: 1.2724
# Epoch 0, Step 29300, Loss: 1.1553
# Epoch 0, Step 29400, Loss: 1.3337
# Epoch 0, Step 29500, Loss: 1.2403
# Epoch 0, Step 29600, Loss: 1.2451
# Epoch 0, Step 29700, Loss: 1.3186
# Epoch 0, Step 29800, Loss: 1.3018
# Epoch 0, Step 29900, Loss: 1.2382
# Epoch 0, Step 30000, Loss: 1.2327
# Epoch 0, Step 30100, Loss: 1.3190
# Epoch 0, Step 30200, Loss: 1.3099
# Epoch 0, Step 30300, Loss: 1.2244
# Epoch 0, Step 30400, Loss: 1.3454
# Epoch 0, Step 30500, Loss: 1.3327
# Epoch 0, Step 30600, Loss: 1.1631
# Epoch 0, Step 30700, Loss: 1.2384
# Epoch 0, Step 30800, Loss: 1.3351
# Epoch 0, Step 30900, Loss: 1.3679
# Epoch 0, Step 31000, Loss: 1.3124
# Epoch 0, Step 31100, Loss: 1.4055
# Epoch 0, Step 31200, Loss: 1.3331
# Epoch 0, Step 31300, Loss: 1.2685
# Epoch 0, Step 31400, Loss: 1.2748
# Epoch 0, Step 31500, Loss: 1.3243
# Epoch 0, Step 31600, Loss: 1.3126
# Epoch 0, Step 31700, Loss: 1.2849
# Epoch 0, Step 31800, Loss: 1.1458
# Epoch 0, Step 31900, Loss: 1.2522
# Epoch 0, Step 32000, Loss: 1.3389
# Epoch 0, Step 32100, Loss: 1.3258
# Epoch 0, Step 32200, Loss: 1.2969
# Epoch 0, Step 32300, Loss: 1.3283
# Epoch 0, Step 32400, Loss: 1.1270
# Epoch 0, Step 32500, Loss: 1.2128
# Epoch 0, Step 32600, Loss: 1.2442
# Epoch 0, Step 32700, Loss: 1.2384
# Epoch 0, Step 32800, Loss: 1.2596
# Epoch 0, Step 32900, Loss: 1.2985
# Epoch 0, Step 33000, Loss: 1.2284
# Epoch 0, Step 33100, Loss: 1.2352
# Epoch 0, Step 33200, Loss: 1.1920
# Epoch 0, Step 33300, Loss: 1.2420
# Epoch 0, Step 33400, Loss: 1.2731
# Epoch 0, Step 33500, Loss: 1.2849
# Epoch 0, Step 33600, Loss: 1.3054
# Epoch 0, Step 33700, Loss: 1.1615
# Epoch 0, Step 33800, Loss: 1.2697
# Epoch 0, Step 33900, Loss: 1.2417
# Epoch 0, Step 34000, Loss: 1.3665
# Epoch 0, Step 34100, Loss: 1.3418
# Epoch 0, Step 34200, Loss: 1.2380
# Epoch 0, Step 34300, Loss: 1.1684
# Epoch 0, Step 34400, Loss: 1.2795
# Epoch 0, Step 34500, Loss: 1.3465
# Epoch 0, Step 34600, Loss: 1.3568
# Epoch 0, Step 34700, Loss: 1.2325
# Epoch 0, Step 34800, Loss: 1.3104
# Epoch 0, Step 34900, Loss: 1.1649
# Epoch 0, Step 35000, Loss: 1.1612
# Epoch 0, Step 35100, Loss: 1.1499
# Epoch 0, Step 35200, Loss: 1.2216
# Epoch 0, Step 35300, Loss: 1.1821
# Epoch 0, Step 35400, Loss: 1.2139
# Epoch 0, Step 35500, Loss: 1.2274
# Epoch 0, Step 35600, Loss: 1.3162
# Epoch 0, Step 35700, Loss: 1.1665
# Epoch 0, Step 35800, Loss: 1.2797
# Epoch 0, Step 35900, Loss: 1.1716
# Epoch 0, Step 36000, Loss: 1.3178
# Epoch 0, Step 36100, Loss: 1.2009
# Epoch 0, Step 36200, Loss: 1.3055
# Epoch 0, Step 36300, Loss: 1.2547
# Epoch 0, Step 36400, Loss: 1.2967
# Epoch 0, Step 36500, Loss: 1.2311
# Epoch 0, Step 36600, Loss: 1.1528
# Epoch 0, Step 36700, Loss: 1.2850
# Epoch 0, Step 36800, Loss: 1.3204
# Epoch 0, Step 36900, Loss: 1.3252
# Epoch 0, Step 37000, Loss: 1.3632
# Epoch 0, Step 37100, Loss: 1.3024
# Epoch 0, Step 37200, Loss: 1.3196
# Epoch 0, Step 37300, Loss: 1.2607
# Epoch 0, Step 37400, Loss: 1.2815
# Epoch 0, Step 37500, Loss: 1.2528
# Epoch 0, Step 37600, Loss: 1.2459
# Epoch 0, Step 37700, Loss: 1.1340
# Epoch 0, Step 37800, Loss: 1.1899
# Epoch 0, Step 37900, Loss: 1.2481
# Epoch 0, Step 38000, Loss: 1.2524
# Epoch 0, Step 38100, Loss: 1.1834
# Epoch 0, Step 38200, Loss: 1.1415
# Epoch 0, Step 38300, Loss: 1.2003
# Epoch 0, Step 38400, Loss: 1.2418
# Epoch 0, Step 38500, Loss: 1.2284
# Epoch 0, Step 38600, Loss: 1.3249
# Epoch 0, Step 38700, Loss: 1.1955
# Epoch 0, Step 38800, Loss: 1.2471
# Epoch 0, Step 38900, Loss: 1.2220
# Epoch 0, Step 39000, Loss: 1.1919
# Epoch 0, Step 39100, Loss: 1.2690
# Epoch 0, Step 39200, Loss: 1.1883
# Epoch 0, Step 39300, Loss: 1.3195
# Epoch 0, Step 39400, Loss: 1.2964
# Epoch 0, Step 39500, Loss: 1.1989
# Epoch 0, Step 39600, Loss: 1.2541
# Epoch 0, Step 39700, Loss: 1.2533
# Epoch 0, Step 39800, Loss: 1.3220
# Epoch 0, Step 39900, Loss: 1.2469
# Epoch 0, Step 40000, Loss: 1.2018
# Epoch 0, Step 40100, Loss: 1.1775
# Epoch 0, Step 40200, Loss: 1.1408
# Epoch 0, Step 40300, Loss: 1.3407
# Epoch 0, Step 40400, Loss: 1.2526
# Epoch 0, Step 40500, Loss: 1.2196
# Epoch 0, Step 40600, Loss: 1.2757
# Epoch 0, Step 40700, Loss: 1.2350
# Epoch 0, Step 40800, Loss: 1.2563
# Epoch 0, Step 40900, Loss: 1.2132
# Epoch 0, Step 41000, Loss: 1.2664
# Epoch 0, Step 41100, Loss: 1.1948
# Epoch 0, Step 41200, Loss: 1.2972
# Epoch 0, Step 41300, Loss: 1.2497
# Epoch 0, Step 41400, Loss: 1.3425
# Epoch 0, Step 41500, Loss: 1.1897
# Epoch 0, Step 41600, Loss: 1.3410
# Epoch 0, Step 41700, Loss: 1.4108
# Epoch 0, Step 41800, Loss: 1.1998
# Epoch 0, Step 41900, Loss: 1.1991
# Epoch 0, Step 42000, Loss: 1.1773
# Epoch 0, Step 42100, Loss: 1.2193
# Epoch 0, Step 42200, Loss: 1.1553
# Epoch 0, Step 42300, Loss: 1.1514
# Epoch 0, Step 42400, Loss: 1.2504
# Epoch 0, Step 42500, Loss: 1.2039
# Epoch 0, Step 42600, Loss: 1.2573
# Epoch 0, Step 42700, Loss: 1.2454
# Epoch 0, Step 42800, Loss: 1.2114
# Epoch 0, Step 42900, Loss: 1.1639
# Validation loss: 1.3699
# Starting generation with random character: t
# Generated text:
# tuard her by his people
# among the Vengeance.  He could turn by
# those answered outside his mother!  Now."
#
#
# But, if the merits of good father on his mind, with thisting burd of Saint Antoine was ordered in his secish how the good order of that time, if cas never so makine, when I heard upon my business."
#
#
# "Haqual patch, with their other dawn hoarse.  It was refisure of it--"
#
#
# He leaned from one of this saying you know it?  (You made to do.  This is legues and one of December!" resolved to Death

# %%
def generate_text(model, start_char, char_to_idx, idx_to_char, max_length=2000):
    model.eval()
    input_idx = torch.tensor([[char_to_idx[start_char]]], dtype=torch.long).to(device)
    generated_text = [start_char]

    hidden_state = None
    with torch.no_grad():
        for _ in range(max_length):
            logits, hidden_state = model(input_idx, hidden_state)  # (1, 1, vocab_size)
            probs = torch.softmax(logits[0, -1, :], dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            next_char = idx_to_char[next_token.item()]
            generated_text.append(next_char)
            input_idx = next_token.unsqueeze(0)

    return ''.join(generated_text)

generated_text = generate_text(model, random_start_char, char_to_idx, idx_to_char)
print("Generated text:")
print(generated_text)
# Out:
# Generated text:
# the beds of the Dorn altogewhere out
# this place, "quite closeness," with most for again, and smulled at the thing left up; any good occasy:  "I think then.  But, I have been their proke, and to see well out of that yourself about her hand and leathing at the passenger, I demand him, of an awn of anybody's head was to shore and soloud and his little opportunity--or a Ungive that.  I saw well vigh look, and you will you can have the immoving the guiler of improvement.  Don't be fell, and was.  Her say, as your Twife to-night; I mean to, and I beginnt him besome you, my soul, my business, it begars, _no," I shall not be made to the knives of the attitud by no other, the knowledge thing, when he
# ever turned out," said the coot with secret and obey wig had reveiged his blue timely consideration.  "What is it it."  He did not have been readies with
# surrounded skees, and on his mind that was sure the Paris.
#
#
# "Be done to me.  Everything at all, if it were hure you feel upon the burying!"
#
#
# "Yes," having fortunished humbly calling a space.  "It is
# pillow!" said Mr. Lorry's.  Otherwise.  "Lid he could come more."
#
#
# His shoulder.  Her good under dear they change and enough in the wall, who, the King took out through such ome sound.  But, remained her that deetre, he had been done.  I dull abuse,
# advourable concluded word, and conscious as a scarles were crowded between this daughter prevense the train of the observation.  Your father after his invisioned shaking up this old private sorrobs of his feet clinging his way that runkered in a pity occupied.  "Never it is sholling to a place with a bedsity.  More and vurious and yet no young lady in Monseigneur."
#
#
# "You will say
# it as soon brought that about, don't you business is to lay it me into the med."
#
#
# "You know me (
#
#
#
#
# Book was his belonging on any God influence with great singuished thread upon her quiet was the spect me she could be before his hander was assertable case, that it has lived back and a gentleman grey?"
#
#
# And
